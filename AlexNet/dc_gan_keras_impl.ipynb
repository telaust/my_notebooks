# %%
import numpy as np
from keras.layers import Input, Dense, Reshape, Flatten, Dropout, BatchNormalization, Activation, ZeroPadding2D
from keras.layers import LeakyReLU, UpSampling2D
from keras.models import Sequential, Model
from keras.optimizers import Adam

# %%
# load needed data set
from keras.datasets import mnist

# %%
class dcgan(object):
    
    def __init__(self, h=28, w=28, c=1):
        self.height = h
        self.width = w
        self.channels = c
        
        self.img_shape = (h, w, c)
        self.latent_dim = 100
        
        self.optimizer = Adam(lr=2e-4)
        
        # build Discr
        self.D = self.build_D()
        # compile it
        self.D.compile(loss='binary_crossentropy', 
                       optimizer=self.optimizer, 
                       metrics=['accuracy'])
        
        
        
    # binary classifier    
    def build_D(self):
        
        model = Sequential()
        # 1st BLOCK
        model.add(Conv2D(32, kernel_size=3, strides=2, input_shape=self.img_shape,padding='same'))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(rate=0.25))
        # 2nd BLOCK
        model.add(Conv2D(64, kernel_size=3, strides=2, padding="same"))
        model.add(ZeroPadding2D(padding=( (0, 1), (0, 1) )))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(rate=0.25))
        # 3rd BLOCK
        model.add(Conv2D(128, kernel_size=3, strides=2, padding="same"))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(rate=0.25))
        # 4th BLOCK
        model.add(Conv2D(256, kernel_size=3, strides=1, padding='same'))
        model.add(BatchNormalization(momentum=0.8))
        model.add(LeakyReLU(alpha=0.2))
        model.add(Dropout(rate=0.25))
        
        model.add(Flatten())
        model.add(Dense(1, activation='sigmoid'))
        
        img = Input(shape=self.img_shape)
        val = model(img)
        
        return Model(img, val)
        
    def build_G(self):
        model = Sequential()
        # 1st BLOCk
        model.add(Dense(128 * 7 * 7, activation='relu', input_dim=self.latent_dim))
        model.add(Reshape((7, 7, 128)))
        model.add(UpSampling2D())
        # 2nd BLOCK
        model.add(Conv2D(128, kernel_size=3, padding='same'))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))
        model.add(UpSampling2D())
        # 3rd BLOCK
        model.add(Conv2D(64, kernel_size=3, padding='same'))
        model.add(BatchNormalization(momentum=0.8))
        model.add(Activation("relu"))
        # 4th BLOCK
        model.add(Conv2D(self.channels, kernel_size=3, padding="same"))
        model.add(Activation("tanh"))
        
        noise = Input(shape=(self.latent_dim,))
        img = model(noise)
        
        return Model(img, noise)

    def train(self, epochs=5, batch_size=128):
        
        
        for ep in range(epochs):
            idx = np.random.randint(0, X_train.shape[0], batch_size)
            imgs = X_train[idx]
